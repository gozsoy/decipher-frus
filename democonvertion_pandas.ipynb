# %%
# Hack to make the module importable
import sys
sys.path.append(r'./../')

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# %load_ext autoreload
# %autoreload 2
from py2neo import Graph, NodeMatcher
import pandas as pd

from rel2graph.relational_modules.pandas import PandasDataframeIterator
from rel2graph import IteratorIterator
from rel2graph import Converter
from rel2graph.utils import load_file
from rel2graph import register_attribute_postprocessor, Attribute
import rel2graph.common_modules

filename = "schema.yaml"

# %%
# Configure Logging
import logging

#logging.basicConfig(level=logging.WARNING)
logger = logging.getLogger("rel2graph")
logger.setLevel(logging.DEBUG)
log_formatter = logging.Formatter("%(asctime)s [%(threadName)s]::[%(levelname)s]::%(filename)s: %(message)s")
console_handler = logging.StreamHandler()
console_handler.setFormatter(log_formatter)
logger.addHandler(console_handler)

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data = {
  "ID": [1,2,2,3,4,4],
  "FirstName": ["Julian", "Fritz",  "Fritz", "Hans", "Rudolfo", "Rudolfo"],
  "LastName": ["Minder", "Generic", "SomeGuy", "Müller", "Muster", "Muster"],
  "FavoriteFlower": ["virginica", "setosa", "setosa", "versicolor", "setosa", "setosa"]
}
people = pd.DataFrame(data)
people
# Out:
#    ID FirstName LastName FavoriteFlower
# 0   1    Julian   Minder      virginica
# 1   2     Fritz  Generic         setosa
# 2   2     Fritz  SomeGuy         setosa
# 3   3      Hans   Müller     versicolor
# 4   4   Rudolfo   Muster         setosa
# 5   4   Rudolfo   Muster         setosa

# %%
graph = Graph(scheme="bolt", host="localhost", port=7687,  auth=('neo4j', 'bos')) ## UPDATE password

graph.delete_all()  # reset graph (only wehn first creating the databse, here for debugging purposes)

# %%
# Now neo4j does not support the numpy dtype int64, so we need to convert it to python native int
# We create a wrapper for this.
@register_attribute_postprocessor
def INT(attribute):
    return Attribute(attribute.key, int(attribute.value))

@register_attribute_postprocessor
def FLOAT(attribute):
    return Attribute(attribute.key, float(attribute.value))

# In the schema file wrap the Person.ID attribute in the INT wrapper
#        + ID = INT(Person.ID)
# Out:
# 2022-12-19 22:25:58,522 [MainThread]::[DEBUG]::registrar.py: Registered attribute postprocessor 'INT''.
# 2022-12-19 22:25:58,523 [MainThread]::[DEBUG]::registrar.py: Registered attribute postprocessor 'FLOAT''.

# %%
iterator = IteratorIterator([PandasDataframeIterator(people, "Person"), PandasDataframeIterator(iris, "Flower")])

# %%
graph.delete_all()

# %%
converter = Converter(load_file(filename), iterator, graph, num_workers=1)
# Out:
# 2022-12-19 22:26:10,291 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['sepal_length', 'sepal_length']
# 2022-12-19 22:26:10,291 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,292 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'FLOAT' with static args []
# 2022-12-19 22:26:10,292 [MainThread]::[DEBUG]::registrar.py: Requested factory 'FLOAT' from registry.
# 2022-12-19 22:26:10,293 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactoryWrapper' from registry.
# 2022-12-19 22:26:10,293 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['sepal_width', 'sepal_width']
# 2022-12-19 22:26:10,294 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,294 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'FLOAT' with static args []
# 2022-12-19 22:26:10,295 [MainThread]::[DEBUG]::registrar.py: Requested factory 'FLOAT' from registry.
# 2022-12-19 22:26:10,295 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactoryWrapper' from registry.
# 2022-12-19 22:26:10,296 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['petal_length', 'petal_length']
# 2022-12-19 22:26:10,296 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,297 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'FLOAT' with static args []
# 2022-12-19 22:26:10,297 [MainThread]::[DEBUG]::registrar.py: Requested factory 'FLOAT' from registry.
# 2022-12-19 22:26:10,298 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactoryWrapper' from registry.
# 2022-12-19 22:26:10,298 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['petal_width', 'petal_width']
# 2022-12-19 22:26:10,299 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,299 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'FLOAT' with static args []
# 2022-12-19 22:26:10,300 [MainThread]::[DEBUG]::registrar.py: Requested factory 'FLOAT' from registry.
# 2022-12-19 22:26:10,300 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactoryWrapper' from registry.
# 2022-12-19 22:26:10,301 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['Flower']
# 2022-12-19 22:26:10,301 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,302 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'NodeFactory' with static args ['flower']
# 2022-12-19 22:26:10,302 [MainThread]::[DEBUG]::registrar.py: Requested factory 'NodeFactory' from registry.
# 2022-12-19 22:26:10,303 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['Name', 'species']
# 2022-12-19 22:26:10,303 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,304 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['Species']
# 2022-12-19 22:26:10,304 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,305 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['BioEntity']
# 2022-12-19 22:26:10,305 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,305 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'NodeFactory' with static args ['Name', 'species']
# 2022-12-19 22:26:10,306 [MainThread]::[DEBUG]::registrar.py: Requested factory 'NodeFactory' from registry.
# 2022-12-19 22:26:10,306 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['is']
# 2022-12-19 22:26:10,307 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,308 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'Matcher' with static args ['flower']
# 2022-12-19 22:26:10,308 [MainThread]::[DEBUG]::registrar.py: Requested factory 'Matcher' from registry.
# 2022-12-19 22:26:10,309 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'Matcher' with static args ['species']
# 2022-12-19 22:26:10,309 [MainThread]::[DEBUG]::registrar.py: Requested factory 'Matcher' from registry.
# 2022-12-19 22:26:10,310 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'RelationFactory' with static args []
# 2022-12-19 22:26:10,310 [MainThread]::[DEBUG]::registrar.py: Requested factory 'RelationFactory' from registry.
# 2022-12-19 22:26:10,311 [MainThread]::[DEBUG]::registrar.py: Requested factory 'SupplyChain' from registry.
# 2022-12-19 22:26:10,311 [MainThread]::[DEBUG]::registrar.py: Requested factory 'SupplyChain' from registry.
# 2022-12-19 22:26:10,311 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['ID', 'ID']
# 2022-12-19 22:26:10,312 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,312 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'INT' with static args []
# 2022-12-19 22:26:10,313 [MainThread]::[DEBUG]::registrar.py: Requested factory 'INT' from registry.
# 2022-12-19 22:26:10,313 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactoryWrapper' from registry.
# 2022-12-19 22:26:10,314 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['FirstName', 'FirstName']
# 2022-12-19 22:26:10,314 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,315 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['LastName', 'LastName']
# 2022-12-19 22:26:10,315 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,315 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['Person']
# 2022-12-19 22:26:10,316 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,317 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'NodeFactory' with static args ['ID', 'person']
# 2022-12-19 22:26:10,317 [MainThread]::[DEBUG]::registrar.py: Requested factory 'NodeFactory' from registry.
# 2022-12-19 22:26:10,318 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['Since', '4ever']
# 2022-12-19 22:26:10,318 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,319 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['likes']
# 2022-12-19 22:26:10,319 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,319 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'Matcher' with static args ['person']
# 2022-12-19 22:26:10,320 [MainThread]::[DEBUG]::registrar.py: Requested factory 'Matcher' from registry.
# 2022-12-19 22:26:10,320 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['Species']
# 2022-12-19 22:26:10,321 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,321 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'AttributeFactory' with static args ['Name', 'FavoriteFlower']
# 2022-12-19 22:26:10,322 [MainThread]::[DEBUG]::registrar.py: Requested factory 'AttributeFactory' from registry.
# 2022-12-19 22:26:10,322 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'Matcher' with static args []
# 2022-12-19 22:26:10,322 [MainThread]::[DEBUG]::registrar.py: Requested factory 'Matcher' from registry.
# 2022-12-19 22:26:10,323 [MainThread]::[DEBUG]::schema_compiler.py: Compiling module 'RelationFactory' with static args []
# 2022-12-19 22:26:10,323 [MainThread]::[DEBUG]::registrar.py: Requested factory 'RelationFactory' from registry.
# 2022-12-19 22:26:10,324 [MainThread]::[DEBUG]::registrar.py: Requested factory 'SupplyChain' from registry.
# 2022-12-19 22:26:10,324 [MainThread]::[DEBUG]::registrar.py: Requested factory 'SupplyChain' from registry.

# %%
converter()
# Out:
# 2022-12-19 22:26:12,885 [MainThread]::[INFO]::converter.py: Running convertion with 1 parallel workers.
# 2022-12-19 22:26:12,886 [MainThread]::[INFO]::converter.py: Starting creation of nodes.
# 2022-12-19 22:26:12,886 [Worker-0]::[DEBUG]::converter.py: Starting Worker 0
# 2022-12-19 22:26:12,888 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 0)
# 2022-12-19 22:26:12,888 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 1)
# 2022-12-19 22:26:12,889 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 2)
# 2022-12-19 22:26:12,890 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 3)
# 2022-12-19 22:26:12,891 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 4)
# 2022-12-19 22:26:12,892 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 5)
# 2022-12-19 22:26:12,893 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 0)
# 2022-12-19 22:26:12,894 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 1)
# 2022-12-19 22:26:12,895 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 2)
# 2022-12-19 22:26:12,896 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 3)
# 2022-12-19 22:26:12,898 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 4)
# 2022-12-19 22:26:12,899 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 5)
# 2022-12-19 22:26:12,900 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 6)
# 2022-12-19 22:26:12,901 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 7)
# 2022-12-19 22:26:12,902 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 8)
# 2022-12-19 22:26:12,904 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 9)
# 2022-12-19 22:26:12,905 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 10)
# 2022-12-19 22:26:12,906 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 11)
# 2022-12-19 22:26:12,907 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 12)
# 2022-12-19 22:26:12,908 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 13)
# 2022-12-19 22:26:12,909 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 14)
# 2022-12-19 22:26:12,910 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 15)
# 2022-12-19 22:26:12,911 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 16)
# 2022-12-19 22:26:12,912 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 17)
# 2022-12-19 22:26:12,913 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row
[Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 1)
# 2022-12-19 22:26:14,000 [Worker-0]::[DEBUG]::matcher.py: Matching based on labels: '['Species']' and conditions: {'Name': 'setosa'}
# 2022-12-19 22:26:14,007 [Worker-0]::[DEBUG]::factory.py: For relation type likes matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,008 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 2)
# 2022-12-19 22:26:14,009 [Worker-0]::[DEBUG]::matcher.py: Matching based on labels: '['Species']' and conditions: {'Name': 'setosa'}
# 2022-12-19 22:26:14,017 [Worker-0]::[DEBUG]::factory.py: For relation type likes matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,018 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 3)
# 2022-12-19 22:26:14,019 [Worker-0]::[DEBUG]::matcher.py: Matching based on labels: '['Species']' and conditions: {'Name': 'versicolor'}
# 2022-12-19 22:26:14,027 [Worker-0]::[DEBUG]::factory.py: For relation type likes matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,029 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 4)
# 2022-12-19 22:26:14,029 [Worker-0]::[DEBUG]::matcher.py: Matching based on labels: '['Species']' and conditions: {'Name': 'setosa'}
# 2022-12-19 22:26:14,038 [Worker-0]::[DEBUG]::factory.py: For relation type likes matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,040 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Person' (row 5)
# 2022-12-19 22:26:14,040 [Worker-0]::[DEBUG]::matcher.py: Matching based on labels: '['Species']' and conditions: {'Name': 'setosa'}
# 2022-12-19 22:26:14,055 [Worker-0]::[DEBUG]::factory.py: For relation type likes matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,056 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 0)
# 2022-12-19 22:26:14,057 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,058 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 1)
# 2022-12-19 22:26:14,059 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,061 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 2)
# 2022-12-19 22:26:14,061 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,063 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 3)
# 2022-12-19 22:26:14,063 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,065 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 4)
# 2022-12-19 22:26:14,066 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,069 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 5)
# 2022-12-19 22:26:14,070 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,071 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 6)
# 2022-12-19 22:26:14,072 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,074 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 7)
# 2022-12-19 22:26:14,075 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,077 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 8)
# 2022-12-19 22:26:14,077 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,079 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 9)
# 2022-12-19 22:26:14,080 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,081 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 10)
# 2022-12-19 22:26:14,082 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,084 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 11)
# 2022-12-19 22:26:14,084 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,086 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 12)
# 2022-12-19 22:26:14,087 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,089 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 13)
# 2022-12-19 22:26:14,089 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,091 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 14)
# 2022-12-19 22:26:14,092 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,094 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 15)
# 2022-12-19 22:26:14,095 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,097 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 16)
# 2022-12-19 22:26:14,098 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,100 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 17)
# 2022-12-19 22:26:14,101 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,103 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 18)
# 2022-12-19 22:26:14,103 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,106 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 19)
# 2022-12-19 22:26:14,107 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,109 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 20)
# 2022-12-19 22:26:14,110 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,112 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 21)
# 2022-12-19 22:26:14,113 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,115 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 22)
# 2022-12-19 22:26:14,116 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,119 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 23)
# 2022-12-19 22:26:14,119 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,122 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 24)
# 2022-12-19 22:26:14,122 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,126 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 25)
# 2022-12-19 22:26:14,126 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,129 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 26)
# 2022-12-19 22:26:14,130 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,133 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 27)
# 2022-12-19 22:26:14,134 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,136 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 28)
# 2022-12-19 22:26:14,137 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,140 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 29)
# 2022-12-19 22:26:14,140 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,143 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 30)
# 2022-12-19 22:26:14,144 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,147 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 31)
# 2022-12-19 22:26:14,147 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,150 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 32)
# 2022-12-19 22:26:14,151 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,154 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 33)
# 2022-12-19 22:26:14,155 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,158 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 34)
# 2022-12-19 22:26:14,158 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14,161 [Worker-0]::[DEBUG]::converter.py: Processing PandasSeriesResource 'Flower' (row 35)
# 2022-12-19 22:26:14,162 [Worker-0]::[DEBUG]::factory.py: For relation type is matched 1 from_nodes and 1 to nodes
# 2022-12-19 22:26:14