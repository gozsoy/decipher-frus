# %%
from py2neo import Graph
import pandas as pd 
from rel2graph.relational_modules.pandas import PandasDataframeIterator 
from rel2graph import IteratorIterator, Converter, Attribute, register_attribute_postprocessor
from rel2graph.utils import load_file

# %%
# Create a connection to the neo4j graph with the py2neo Graph object
graph = Graph(scheme="bolt", host="localhost", port=7687,  auth=('neo4j', 'bos'))

# %%
import pandas as pd
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
iris_iterator = PandasDataframeIterator(iris, "Flower")

# register a custom data processing function
@register_attribute_postprocessor
def append(attribute, append_string):
    new_attribute = Attribute(attribute.key, attribute.value + append_string)
    return new_attribute

# Create IteratorIterator
iterator = IteratorIterator([iris_iterator])

# Create converter instance with schema, the final iterator and the graph
converter = Converter(load_file("iris.yaml"), iterator, graph)
# Start the conversion
converter()
# Out:
# Py2neo Exception 'TypeError': Values of type <class 'numpy.float64'> are not supported
# Sleeping for 10 second and retrying commit
# Values of type <class 'numpy.float64'> are not supported
# Cleaning up...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:218, in Worker._commit_wrap(function)
#     217 try:
# --> 218     function()
#     219 except Exception as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:233, in Worker.commit_batch.<locals>.<lambda>()
#     232 with self._config.graph_lock:
# --> 233     Worker._commit_wrap(lambda: self._config.graph.create(self.to_create))
#     234 nodes_committed += len(self.to_create.nodes)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:591, in Graph.create(self, subgraph)
#     585 """ Run a :meth:`~py2neo.Transaction.create` operation within a
#     586 :class:`~py2neo.Transaction`.
#     587
#     588 :param subgraph: a :class:`.Node`, :class:`.Relationship` or other
#     589                :class:`.Subgraph`
#     590 """
# --> 591 self.update(lambda tx: tx.create(subgraph))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:445, in Graph.update(self, cypher, parameters, timeout)
#     444 if parameters is None:
# --> 445     self._update(cypher, timeout=timeout)
#     446 elif (isinstance(parameters, tuple) and len(parameters) == 2 and
#     447         isinstance(parameters[0], Sequence) and isinstance(parameters[1], Mapping)):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:470, in Graph._update(self, f, timeout)
#     467 tx = self.begin(
#     468                 # after=after, metadata=metadata, timeout=timeout
#     469                 )
# --> 470 value = f(tx)
#     471 if isgenerator(value):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:591, in Graph.create.<locals>.<lambda>(tx)
#     585 """ Run a :meth:`~py2neo.Transaction.create` operation within a
#     586 :class:`~py2neo.Transaction`.
#     587
#     588 :param subgraph: a :class:`.Node`, :class:`.Relationship` or other
#     589                :class:`.Subgraph`
#     590 """
# --> 591 self.update(lambda tx: tx.create(subgraph))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:1063, in Transaction.create(self, subgraph)
#    1062 else:
# -> 1063     create(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/data.py:200, in Subgraph.__db_create__(self, tx)
#     199 pq = cypher_join(pq, "RETURN id(_)")
# --> 200 records = tx.run(*pq)
#     201 for i, record in enumerate(records):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:987, in Transaction.run(self, cypher, parameters, **kwparameters)
#     986 if self.ref:
# --> 987     result = self._connector.run(self.ref, cypher, parameters)
#     988 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/__init__.py:1424, in Connector.run(self, tx, cypher, parameters)
#    1423 try:
# -> 1424     return cx.run(tx, cypher, parameters)
#    1425 except (ConnectionUnavailable, ConnectionBroken):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:595, in Bolt1.run(self, tx, cypher, parameters)
#     594 self._assert_transaction_open(tx)
# --> 595 return self._run(tx.graph_name, cypher, parameters or {})
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:947, in Bolt3._run(self, graph_name, cypher, parameters, extra, final)
#     946 def _run(self, graph_name, cypher, parameters, extra=None, final=False):
# --> 947     response = self.append_message(0x10, cypher, parameters, extra or {})
#     948     result = BoltResult(self._transaction, self, response)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:750, in Bolt1.append_message(self, tag, *fields, **kwargs)
#     749     vital = False
# --> 750 self.write_message(tag, fields)
#     751 response = BoltResponse(capacity=capacity, vital=vital)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:725, in Bolt1.write_message(self, tag, fields)
#     724 else:
# --> 725     self._writer.write_message(tag, fields)
#     726     self._log_message(self.local_port, tag, fields)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:264, in BoltMessageWriter.write_message(self, tag, fields)
#     263 for field in fields:
# --> 264     packer.pack(field)
#     265 buffer.truncate()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:151, in Packer.pack(self, value)
#     150 elif t is dict or t is OrderedDict or isinstance(value, self.dict_type):
# --> 151     self._pack_dict(value)
#     153 # Bolt 2 introduced temporal and spatial types
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:285, in Packer._pack_dict(self, value)
#     283     raise TypeError("Dictionary keys must be "
#     284                     "of type %r or bytes" % self.text_type)
# --> 285 self.pack(item)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:120, in Packer.pack(self, value)
#     119 elif t is self.list_type or t is tuple:
# --> 120     self._pack_list(value)
#     122 # Integer
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:247, in Packer._pack_list(self, value)
#     246 for item in value:
# --> 247     self.pack(item)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:151, in Packer.pack(self, value)
#     150 elif t is dict or t is OrderedDict or isinstance(value, self.dict_type):
# --> 151     self._pack_dict(value)
#     153 # Bolt 2 introduced temporal and spatial types
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:285, in Packer._pack_dict(self, value)
#     283     raise TypeError("Dictionary keys must be "
#     284                     "of type %r or bytes" % self.text_type)
# --> 285 self.pack(item)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:200, in Packer.pack(self, value)
#     198 # Other
#     199 else:
# --> 200     raise TypeError("Values of type %s are not supported" % type(value))
#
# TypeError: Values of type <class 'numpy.float64'> are not supported
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/gokberk/Desktop/eth_courses/decipher-frus/conversion.ipynb Cell 4 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/gokberk/Desktop/eth_courses/decipher-frus/conversion.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> converter = Converter(load_file("iris.yaml"), iterator, graph)
#      <a href='vscode-notebook-cell:/Users/gokberk/Desktop/eth_courses/decipher-frus/conversion.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a> # Start the conversion
# ---> <a href='vscode-notebook-cell:/Users/gokberk/Desktop/eth_courses/decipher-frus/conversion.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> converter()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:585, in Converter.__call__(self, progress_bar, skip_nodes, skip_relations)
#     582 logger.info("Starting creation of nodes.")
#     584 try:
# --> 585     self._worker_pool.run()
#     586 except KeyboardInterrupt as e:
#     587     # KeyboardInterrupt is raised on the main exec thread
#     588     # -> Cleanup all workers
#     589     self._worker_pool.interrupt()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:421, in WorkerPool.run(self)
#     419 self.interrupt()
#     420 self.join()
# --> 421 raise exc_obj
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:336, in Worker.run(self)
#     334 logger.debug(f"Starting Worker " + str(self._worker_id))
#     335 try:
# --> 336     self.process()
#     337 except Exception as err:
#     338     logger.error(str(err))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:266, in Worker.process(self)
#     264 while not self._exit_flag:
#     265     if buffer_size % self._config.buffer_size == 0:
# --> 266         self.commit_batch()
#     267         buffer_size = 0
#     269     if self._work_item is not None:
#     270         # We first test if the worker still has a work item (happens if exception gets raised during execution)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:233, in Worker.commit_batch(self)
#     231 if len(self.to_create.nodes) + len(self.to_create.relationships) > 0:
#     232     with self._config.graph_lock:
# --> 233         Worker._commit_wrap(lambda: self._config.graph.create(self.to_create))
#     234     nodes_committed += len(self.to_create.nodes)
#     235     relations_committed += len(self.to_create.relationships)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:223, in Worker._commit_wrap(function)
#     221 logger.error("Sleeping for 10 second and retrying commit")
#     222 time.sleep(10)
# --> 223 function()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rel2graph/core/converter.py:233, in Worker.commit_batch.<locals>.<lambda>()
#     231 if len(self.to_create.nodes) + len(self.to_create.relationships) > 0:
#     232     with self._config.graph_lock:
# --> 233         Worker._commit_wrap(lambda: self._config.graph.create(self.to_create))
#     234     nodes_committed += len(self.to_create.nodes)
#     235     relations_committed += len(self.to_create.relationships)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:591, in Graph.create(self, subgraph)
#     584 def create(self, subgraph):
#     585     """ Run a :meth:`~py2neo.Transaction.create` operation within a
#     586     :class:`~py2neo.Transaction`.
#     587
#     588     :param subgraph: a :class:`.Node`, :class:`.Relationship` or other
#     589                    :class:`.Subgraph`
#     590     """
# --> 591     self.update(lambda tx: tx.create(subgraph))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:445, in Graph.update(self, cypher, parameters, timeout)
#     443 if callable(cypher):
#     444     if parameters is None:
# --> 445         self._update(cypher, timeout=timeout)
#     446     elif (isinstance(parameters, tuple) and len(parameters) == 2 and
#     447             isinstance(parameters[0], Sequence) and isinstance(parameters[1], Mapping)):
#     448         self._update(lambda tx: cypher(tx, *parameters[0], **parameters[1]),
#     449                      timeout=timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:470, in Graph._update(self, f, timeout)
#     466 try:
#     467     tx = self.begin(
#     468                     # after=after, metadata=metadata, timeout=timeout
#     469                     )
# --> 470     value = f(tx)
#     471     if isgenerator(value):
#     472         _ = list(value)     # exhaust the generator
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:591, in Graph.create.<locals>.<lambda>(tx)
#     584 def create(self, subgraph):
#     585     """ Run a :meth:`~py2neo.Transaction.create` operation within a
#     586     :class:`~py2neo.Transaction`.
#     587
#     588     :param subgraph: a :class:`.Node`, :class:`.Relationship` or other
#     589                    :class:`.Subgraph`
#     590     """
# --> 591     self.update(lambda tx: tx.create(subgraph))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:1063, in Transaction.create(self, subgraph)
#    1061     raise TypeError("No method defined to create object %r" % subgraph)
#    1062 else:
# -> 1063     create(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/data.py:200, in Subgraph.__db_create__(self, tx)
#     198 pq = unwind_create_nodes_query(list(map(dict, nodes)), labels=labels)
#     199 pq = cypher_join(pq, "RETURN id(_)")
# --> 200 records = tx.run(*pq)
#     201 for i, record in enumerate(records):
#     202     node = nodes[i]
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/database.py:987, in Transaction.run(self, cypher, parameters, **kwparameters)
#     985 parameters = dict(parameters or {}, **kwparameters)
#     986 if self.ref:
# --> 987     result = self._connector.run(self.ref, cypher, parameters)
#     988 else:
#     989     result = self._connector.auto_run(cypher, parameters,
#     990                                       graph_name=self.graph.name,
#     991                                       readonly=self.readonly)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/__init__.py:1424, in Connector.run(self, tx, cypher, parameters)
#    1422 cx = self._reacquire(tx)
#    1423 try:
# -> 1424     return cx.run(tx, cypher, parameters)
#    1425 except (ConnectionUnavailable, ConnectionBroken):
#    1426     self.prune(cx.profile)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:595, in Bolt1.run(self, tx, cypher, parameters)
#     593     raise ValueError("Transaction is None")
#     594 self._assert_transaction_open(tx)
# --> 595 return self._run(tx.graph_name, cypher, parameters or {})
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:947, in Bolt3._run(self, graph_name, cypher, parameters, extra, final)
#     946 def _run(self, graph_name, cypher, parameters, extra=None, final=False):
# --> 947     response = self.append_message(0x10, cypher, parameters, extra or {})
#     948     result = BoltResult(self._transaction, self, response)
#     949     self._transaction.append(result, final=final)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:750, in Bolt1.append_message(self, tag, *fields, **kwargs)
#     748 if vital is None:
#     749     vital = False
# --> 750 self.write_message(tag, fields)
#     751 response = BoltResponse(capacity=capacity, vital=vital)
#     752 self._responses.append(response)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:725, in Bolt1.write_message(self, tag, fields)
#     723     self._log_message(self.local_port, tag, preview)
#     724 else:
# --> 725     self._writer.write_message(tag, fields)
#     726     self._log_message(self.local_port, tag, fields)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/py2neo/client/bolt.py:264, in BoltMessageWriter.write_message(self, tag, fields)
#     262 packer = Packer(buffer, version=self.protocol_version)
#     263 for field in fields:
# --> 264     packer.pack(field)
#     265 buffer.truncate()
#     266 buffer.seek(0)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:151, in Packer.pack(self, value)
#     149 # Dictionary
#     150 elif t is dict or t is OrderedDict or isinstance(value, self.dict_type):
# --> 151     self._pack_dict(value)
#     153 # Bolt 2 introduced temporal and spatial types
#     154 elif self.version < (2, 0):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:285, in Packer._pack_dict(self, value)
#     282 else:
#     283     raise TypeError("Dictionary keys must be "
#     284                     "of type %r or bytes" % self.text_type)
# --> 285 self.pack(item)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:120, in Packer.pack(self, value)
#     118 # List
#     119 elif t is self.list_type or t is tuple:
# --> 120     self._pack_list(value)
#     122 # Integer
#     123 elif t in self.integer_types:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:247, in Packer._pack_list(self, value)
#     245     raise ValueError("List too large")
#     246 for item in value:
# --> 247     self.pack(item)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:151, in Packer.pack(self, value)
#     149 # Dictionary
#     150 elif t is dict or t is OrderedDict or isinstance(value, self.dict_type):
# --> 151     self._pack_dict(value)
#     153 # Bolt 2 introduced temporal and spatial types
#     154 elif self.version < (2, 0):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:285, in Packer._pack_dict(self, value)
#     282 else:
#     283     raise TypeError("Dictionary keys must be "
#     284                     "of type %r or bytes" % self.text_type)
# --> 285 self.pack(item)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/interchange/packstream.py:200, in Packer.pack(self, value)
#     196     self._pack_point(value)
#     198 # Other
#     199 else:
# --> 200     raise TypeError("Values of type %s are not supported" % type(value))
#
# TypeError: Values of type <class 'numpy.float64'> are not supported
