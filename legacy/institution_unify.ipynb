# %%
import re
import copy
import glob 
import math
import itertools
import jellyfish
from tqdm import tqdm
import pandas as pd
import numpy as np
from datetime import datetime
import xml.etree.ElementTree as ET
from nltk.tokenize import RegexpTokenizer
import ray
tokenizer = RegexpTokenizer(r'\w+')

# define namespaces in FRUS schema
ns = {'xml': 'http://www.w3.org/XML/1998/namespace',
      'dflt': 'http://www.tei-c.org/ns/1.0',
      'frus': 'http://history.state.gov/frus/ns/1.0',
      'xi': 'http://www.w3.org/2001/XInclude'
      }

# define path to save extracted files
tables_path = 'tables/tables_52_88_demo/'

# only use documents within these years
start_year, end_year = 1952, 1958

# %%
# helper function 1 step 0
# parses term item and extracts name, id, description
def extract_institution(item, file):
    volume = file[8:-4]

    term_item = item.find('.//dflt:term[@xml:id]', ns)

    if term_item is not None:

        term_text = "".join(term_item.itertext())
        term_id = term_item.attrib['{http://www.w3.org/XML/1998/namespace}id']

        all_text = "".join(item.itertext())
        end_idx = all_text.find(term_text) + len(term_text+',')
        item_descp = " ".join(all_text[end_idx:].split())

        term_name = " ".join(re.sub(',',''," ".join(term_text.split(', ')[::-1])).split())

        term_id = volume + '_' + term_id

    return {'id':term_id, 'name':term_name, 'description':item_descp.lower()}


# helper function 1 step 1
def aux(row):
    global unified_term_dict

    if row['description'] in unified_term_dict:
      
        temp_dict = unified_term_dict[row['description']]

        temp_dict['id_list'].append(row['id'])
        temp_dict['name_list'].append(row['name'])
    
    else:
        unified_term_dict[row['description']]= {'id_list':[row['id']],
                                            'name_list':[row['name']]}

    return


# helper function 1 step 2
def aux2(row):
    global new_unified_institution_dict

    if row['description_set'] in new_unified_institution_dict:
      
        temp_dict = new_unified_institution_dict[row['description_set']]

        temp_dict['description_list'].append(row['description'])
        temp_dict['id_list'] += row['id_list']
        temp_dict['name_list'] += row['name_list']
    
    else:
        new_unified_institution_dict[row['description_set']]= {'description_list':[row['description']],
                                                                'id_list':row['id_list'],
                                                                'name_list':row['name_list']}

    return


# helper function 1 step 3
# computes similarity between two str acc to func
def compute_sim(s1,func,s2):
    return func(s1,s2)

# helper function 2 step 3
# for a given name computes its string similarity to all other names
# does this for all names separetely
@ray.remote
def find_matches(idx):
    
    s2 = all_descriptions[idx]

    spiro_dist_df = pd.DataFrame(
        {'description_set': all_descriptions,
         'dam_lev_dist': 
         [compute_sim(x, jellyfish.damerau_levenshtein_distance, s2) 
          for x in all_descriptions],
         'jaro_sim': 
         [compute_sim(x, jellyfish.jaro_winkler_similarity, s2) 
          for x in all_descriptions]})
    
    # misspelling check - hyperparameter
    misspelling_idx = set(
        spiro_dist_df[(spiro_dist_df['dam_lev_dist'] <= 2)].index.values)

    return misspelling_idx

# %% [markdown]
# ### STEP 0: extract term annotations from each volume

# %%
global_term_list = []

no_annotation_cnt = 0

for file in tqdm(glob.glob('volumes/frus*')):

    file_start_year = int(file[12:16])
    
    if file_start_year >= start_year and file_start_year<=end_year:

        tree = ET.parse(file)
        root = tree.getroot()
        terms_section = root.find("./dflt:text/dflt:front//dflt:div[@xml:id='terms']", ns)
        
        if terms_section:
            for item in terms_section.findall('.//dflt:item/dflt:hi/dflt:term[@xml:id]/../..', ns):
                term_dict = extract_institution(item, file)
                global_term_list.append(term_dict)
            for item in terms_section.findall('.//dflt:item/dflt:term[@xml:id]/..', ns):
                term_dict = extract_institution(item, file)
                global_term_list.append(term_dict)
        else:
            print(f'No term annotation in {file}.')
            no_annotation_cnt += 1


institution_df = pd.DataFrame(global_term_list)

print(f'Not annotated volume count: {no_annotation_cnt}')
print(f'Row count: {len(institution_df)}')
print('Step 0 finished.')
# Out:
# 100%|██████████| 543/543 [00:11<00:00, 46.46it/s]
# Not annotated volume count: 0
# Row count: 16378
# Step 0 finished.

# %% [markdown]
# #### step 1: reduce exactly matched institution descriptions

# %%
unified_term_dict = {}
institution_df.apply(lambda x:aux(x), axis=1)
unified_institution_df = pd.DataFrame.from_dict(unified_term_dict,orient='index').reset_index(drop=False)
unified_institution_df.rename(columns={'index':'description'}, inplace=True)

print(f'Row count: {len(unified_institution_df)}')
print('Step 1 finished.')
# Out:
# Row count: 4477
# Step 1 finished.

# %% [markdown]
# #### step 2: reduce descriptions with exactly same words but different combinations

# %%
unified_institution_df['description_set'] = unified_institution_df.description.apply(lambda x: " ".join(sorted(x.split())))
new_unified_institution_dict = {}

unified_institution_df.apply(lambda x:aux2(x), axis=1)

new_unified_institution_df = pd.DataFrame.from_dict(new_unified_institution_dict,orient='index').reset_index(drop=False)
new_unified_institution_df.rename(columns={'index':'description_set'}, inplace=True)

print(f'Row count: {len(new_unified_institution_df)}')
print('Step 2 finished.')
# Out:
# Row count: 4444
# Step 2 finished.

# %% [markdown]
# #### step 3: find and reduce obvious misspellings

# %%
all_descriptions = new_unified_institution_df['description_set'].values

# find typos for each name againts others
ray.init(num_cpus=13)
futures = [find_matches.remote(idx) 
            for idx in range(len(all_descriptions))]
result_tuple_list = ray.get(futures)
ray.shutdown()

# name : matched names dict
t = {}
for idx in range(len(all_descriptions)):
    t[idx] = result_tuple_list[idx]
# Out:
# ---------------------------------------------------------------------------
# RayTaskError(TypeError)                   Traceback (most recent call last)
# Cell In[6], line 7
#       4 ray.init(num_cpus=13)
#       5 futures = [find_matches.remote(idx)
#       6             for idx in range(len(all_descriptions))]
# ----> 7 result_tuple_list = ray.get(futures)
#       8 ray.shutdown()
#      10 # name : matched names dict
#
# File ~/Desktop/eth_courses/decipher-frus/unified_env/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/Desktop/eth_courses/decipher-frus/unified_env/lib/python3.8/site-packages/ray/worker.py:1733, in get(object_refs, timeout)
#    1731     worker.core_worker.dump_object_store_memory_usage()
#    1732 if isinstance(value, RayTaskError):
# -> 1733     raise value.as_instanceof_cause()
#    1734 else:
#    1735     raise value
#
# RayTaskError(TypeError): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,863	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,865	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,866	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,868	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,869	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,870	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,872	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,874	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,875	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,877	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8866, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,878	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,879	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,881	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,882	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,884	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,885	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,886	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,887	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,888	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,890	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,891	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,892	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,893	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,895	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,896	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8866, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,897	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,898	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,900	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,901	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8866, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,902	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,903	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,905	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,906	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,907	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,909	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,911	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,912	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,913	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,914	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,916	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,917	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,918	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,919	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,920	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,921	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,923	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,924	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,925	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,927	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,929	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,930	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,932	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,934	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,935	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,936	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,937	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,940	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,941	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8866, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,943	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,946	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,947	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,948	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,958	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,962	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,964	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,965	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,966	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,967	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,968	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,969	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,970	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,971	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,973	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,974	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,975	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,977	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,978	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,979	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,980	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,982	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,983	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,984	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,985	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,986	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,987	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,988	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8866, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,990	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,991	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,993	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,994	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,996	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,998	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:49,999	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,000	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,004	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,006	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,008	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,009	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,010	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,011	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,013	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,015	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,018	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,021	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,023	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,025	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,026	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,027	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,028	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,029	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,030	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,031	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,032	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# ...
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,165	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,166	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,170	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,172	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,173	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,175	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,176	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,177	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,178	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,179	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,180	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,181	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8866, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,182	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,183	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8866, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,184	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,186	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8863, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,187	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,188	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8860, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,190	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,192	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8858, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,194	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,195	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8859, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,197	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,198	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8867, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,199	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,200	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,201	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,202	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8868, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,203	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8856, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,204	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,205	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8865, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,206	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,207	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,208	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,209	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8861, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,211	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8857, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,212	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8862, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected
# 2023-05-09 13:57:50,213	ERROR worker.py:85 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::find_matches() (pid=8864, ip=127.0.0.1)
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in find_matches
#   File "/var/folders/r_/jwmzgr6s6_762bz0h7x_qll40000gn/T/ipykernel_8821/1061217616.py", line 74, in <listcomp>
# TypeError: str argument expected

# %%
'''all_descriptions = new_unified_institution_df['description_set'].values

t = {}
for idx in tqdm(range(len(all_descriptions))):
    name = all_descriptions[idx]
    t[idx]=find_matches(name)'''


scratch_t = copy.deepcopy(t)
changed_flag = True

while changed_flag:

    changed_flag = False

    for key in t:
        
        for matched_idx in t[key]:

            if key != matched_idx:
                if scratch_t.get(key, None) and scratch_t.get(matched_idx, None):
                    changed_flag = True
                    t[key] = t[key].union(t[matched_idx])
                    scratch_t.pop(matched_idx, None)
        
    unwanted = set(t.keys()) - set(scratch_t.keys())
    print(f'removing {len(unwanted)} keys.')
    for unwanted_key in unwanted: del t[unwanted_key]
    scratch_t = copy.deepcopy(t)
    print('---')

for temp_key in t:
    
    te_df = new_unified_institution_df.iloc[list(t[temp_key])]

    name_list = list(itertools.chain.from_iterable(te_df['name_list'].values))
    id_list = list(itertools.chain.from_iterable(te_df['id_list'].values))
    description_list = list(itertools.chain.from_iterable(te_df['description_list'].values))

    new_unified_institution_df.at[temp_key, 'name_list'] = name_list
    new_unified_institution_df.at[temp_key, 'id_list'] = id_list
    new_unified_institution_df.at[temp_key, 'description_list'] = description_list

new_unified_institution_df = new_unified_institution_df.loc[t.keys()]

# save unified term table
new_unified_institution_df.to_parquet(tables_path+'unified_term_df.parquet')

print(f'Row count: {len(new_unified_institution_df)}')
print('Step 3 finished.')

print('finished.')
